# %% [markdown]
# # Deep Learning con PyTorch
#
# ## Índice del Curso
#
# Bienvenido al curso de Deep Learning. Este material cubre desde los fundamentos teóricos hasta implementaciones prácticas con PyTorch.
#
# ---
#
# ## 📚 Contenido Teórico
#
# | Notebook | Tema | Descripción |
# |----------|------|-------------|
# | `DL_01_fundamentos.ipynb` | **Fundamentos** | Perceptrón, funciones de activación, backpropagation |
# | `DL_02_pytorch_basico.ipynb` | **PyTorch Básico** | Tensores, autograd, módulos nn |
# | `DL_03_arquitecturas.ipynb` | **Arquitecturas** | MLP, CNN, RNN/LSTM, Autoencoders |
# | `DL_04_entrenamiento.ipynb` | **Entrenamiento** | Optimización, regularización, callbacks |
#
# ---
#
# ## 🔧 Código Base
#
# El directorio `02_fundamentos/core/` contiene las implementaciones:
#
# - `modelos.py` - Arquitecturas: MLP, CNN, LSTM, Autoencoder, VAE
# - `entrenamiento.py` - Entrenador, EarlyStopping, schedulers
# - `utils.py` - Carga de datos, visualización, checkpointing
#
# ---
#
# ## 💻 Ejemplos Prácticos
#
# El directorio `02_fundamentos/ejemplos/` contiene scripts ejecutables:
#
# | Script | Tarea | Modelo |
# |--------|-------|--------|
# | `ejemplo_mlp_mnist.py` | Clasificación dígitos | MLP |
# | `ejemplo_cnn_cifar10.py` | Clasificación imágenes | CNN |
# | `ejemplo_lstm_sentimientos.py` | Análisis de texto | LSTM |
#
# ---
#
# ## 🚀 Proyectos
#
# El directorio `03_proyectos/` contiene proyectos completos:
#
# 1. **Clasificación de Imágenes** - Transfer learning con modelos preentrenados
# 2. **NLP Sentimientos** - Análisis de sentimientos en reviews
# 3. **Series Temporales** - Predicción con redes recurrentes
#
# ---
#
# ## 📋 Requisitos
#
# ```bash
# pip install -r requirements.txt
# ```
#
# - Python 3.9+
# - PyTorch 2.0+
# - torchvision
# - numpy, pandas, matplotlib
# - scikit-learn
# - tqdm

# %%
# Verificar instalación
import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA disponible: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
